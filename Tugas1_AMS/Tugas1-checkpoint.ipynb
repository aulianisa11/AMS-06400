# %% [markdown]
# nama : Aulia khoirun Nisa

# %% [markdown]
# NIM : A12.2020.06400

# %% [markdown]
# ## Eksperimen dan pengumpulan dataset

# %% [markdown]
# ## Pemanggilan Liberaly 1

# %%
import pandas as pd
import time
import tweepy
import numpy as np

# %%
def twitter_config():
    """
    Fungsi utilitas untuk mengkonfigurasi konsumsi file API Twitter dengan␣
    ,!kunci yang disediakan.
    """
    
    # Autentikasi dan akses menggunakan keys
    auth = tweepy.OAuthHandler("ln7aq4kiFD5dmLjXwkhLt77VL","F7PxNt4DK3kuBwABxj4kYlYs9wQZgOkHUy8ZVSjClT4Z7UGRnd")
    auth.set_access_token("1575101006647795714-HEanY2TljJppJceaJLP0nDbbFOqAJv","G6bBZsgXhqRZ5IcTnTpl8XQL4EmSizLUC1rBvy1WGLQHe")
    
    # Kembalikan akses ke API
    api = tweepy.API(auth)
    try:
        api.verify_credentials()
        print("Authentication OK")
    except:
        print("Error during authentication")
    return api

# %%
# Membuat extractor object
extractor = twitter_config()
# Out:
# Authentication OK

# %% [markdown]
# Ambil tweet dari Username

# %% [markdown]
# Username yang saya gunakan yakni @Raden Rauf AM

# %%
tweets = extractor.user_timeline(screen_name="radenrauf", count=1000)
print("Tweets terambil: {}.\n".format(len(tweets)))

print("100 tweet teratas:\n")
for tweet in tweets[:100]:
    print(tweet.text)
    print()
# Out:
# Tweets terambil: 198.
#
# 100 tweet teratas:
#
# Gimana Malam Minggunya?
# Dah dapet?
#
# RT @Anaknyagakbaik: @radenrauf Kasih tau cara dapetin kmu donk 🥺🥺 #lovestory https://t.co/DD4SR3Lvaq
#
# RT @cuma_narasi: @radenrauf #LoveStory  Apa aku harus pakai asuransi biar dapet kamu yang always listening always understanding https://t.c…
#
# RT @aahnitta: @radenrauf Dasar otak,bukan nya di isi ilmu malah di isi kamu hehe
#
# #LoveStory https://t.co/EI5ttZHWjy
#
# RT @merrynblla: @radenrauf Malming ujan udh pasti doa nya jomblo nih terkabul🤣 #lovestory https://t.co/U8FJx2ls5z
#
# DEAR TWITTER, PLEASEE DO YOUR MAGIC!
#
# Biro Jodoh Love Story dimulai!!!
#
# Temukan jodoh untuk jomblo yang reply deng… https://t.co/Asuh2mszuV
#
# RT @stfusaff: @radenrauf bisa gtu sambelnya😭
#
# RT @osealov: @radenrauf https://t.co/YcH5sigCJ1
#
# RT @nadhifanfs_: @radenrauf Cuangki bang https://t.co/UFI2NFt2Ha
#
# Sore sore ujan ujan emang paling bener makan Bakso, mariii. https://t.co/nwFr6hy10C
#
# Kalau dia ilang ilangan mulu positif thinking aja mungkin emang dia setan, wlwlwlw canda setan.
#
# Pacaran ko ilang… https://t.co/ZgNyn6u5xs
#
# RT @shilvi_setya: Tak de
#
# RT @etra_pii: Tidur dg tenang setelah beberapa waktu ini lelah dihantam kerjaan dan lingkungan.
#
# Malam ini Malam Minggu, apa rencana menarikmu? Pasti ada dong ya kan.
#
# Giliran udah pergi nyesel, pas masih ada dicuekin.
# Kebiasaan.
#
# Tidak semua orang berhak mendapatkan kesempatan kedua.
#
# Selamat buat para pemenang GrabFood #RestoLegendaris!
# @rahmadsaifulhs @hollathemoon @nuranissaj @dieliatin… https://t.co/7IoFznpFHL
#
# Nanti akan ada waktunya giliran kamu, Allah udah nyiapin yang terbaik. Jadi jangan berhenti sekarang ya.
#
# Ada hal hal yang memang lebih baik kita gatau aja, daripada malah bikin ga tenang dan sakit hati sendiri.
#
# You should be proud of yourself, for not giving up.
#
# Hidup itu sederhana, kadang pikiran kita yang membuatnya rumit.
#
# BESOK WEEKEND.
# KAMU BERHAK BERSENANG SENANG.
#
# Sesuatu yang didapatkan dengan kerja keras emang selalu lebih membahagiakan. https://t.co/35uyi9R4CV
#
# Hari Jumat hari baik, semoga hari ini penuh dengan kabar baik.
# Tetap jadi orang baik ya.
#
# Banjir, macet dimana mana, capek ya?
# Sama.
#
# Pengennya dihargai tapi tidak bisa menghargai orang lain, jangan gitu.
#
# Satu lagi, jangan lupa menghargai diri send… https://t.co/HJVHaXtu8h
#
# Mau sebaik apapun kamu, kalau dia gabisa menghargai ya tetep aja terlihat kurang terus.
#
# Selamat berbuka puasa bagi yang menjalankannya 🥰 https://t.co/Lx66ALxcQS
#
# Makin dewasa makin mencari ketenangan dalam hidup.
#
# Terlalu serius memikirkan ujungnya sampai lupa untuk menikmati prosesnya.
# Tetep enjoy your life ya👌🏻
#
# Udah dewasa, temen dikit gapapa, yang penting temennya sama sama supportif aja, ga banyak drama.
#
# Jangan ragu untuk melangkah pergi dari orang orang yang selalu bikin lu sakit hati.
#
# RT @anstsyakath: banyaakkk... ketawa ga jelasnya, gandeng tangan kemanapun, bahkan kalo ga malu digendong bakal digendong deh wkwk
#
# @Sesa_Opas Monmaap keluar bareng itu maksudnya jalan bareng kan? Ya kaaan
#
# RT @Jihannblh: @radenrauf Act of servicenya
#
# RT @HapsariYemima: @radenrauf His lovely and sweet texts
#
# RT @xxrstmsd: @radenrauf Lucu, slalu bisa bikin good mood, bisa cerita apapun
#
# Yang paling kamu kangenin dari dia apa?
#
# Janji ga berantem sama pikiran sendiri?
#
# Love yourself first, yang lainnya bisa nanti.
#
# RT @ceripuffs: @radenrauf @GrabID Bismillah menang. Menang dong pelase total savings hampir sejuta dikit lagi ygy #GrabUnlimited https://t.…
#
# RT @synthiabangun: @radenrauf @GrabID semoga ini rejeki aku, berhubung setengah gaji lari ke Grab semua.. 🤣 #GrabUnlimited https://t.co/p5K…
#
# RT @cheesyclou: @radenrauf @GrabID Total savings ni kak #GrabUnlimited yuk bisa yuk 😍🥰 https://t.co/HJPC6j5eG1
#
# RT @anazadsu_22: @radenrauf @GrabID Total Savings ku #GrabUnlimited https://t.co/CIYQYcoogH
#
# RT @loireorzla: @radenrauf @GrabID HUAAAA MAUUUU BISMILLAH MANTAP DAHUYYYY🤸🏻‍♀️🏋🏻‍♀️  #GrabUnlimited https://t.co/5wP4pOFzxp
#
# RT @hellokeny: @radenrauf @GrabID #GrabUnlimited udah hemat segini om hehe 💚 https://t.co/AqNwIIcEYz
#
# Gais, buat yang bingung. Jadi yang udah langganan #GrabUnlimited:
# 1. kalian buka aplikasi Grab,
# 2. masuk ke "Accou… https://t.co/F1Lne2OzkK
#
# GIVEAWAY 3 iPhone 12 Mini &amp; OVO Cash 5JT (500rb/org)!
#
# Jadi gua sama @grabid mau bikin giveaway utk dibagi ke 13 or… https://t.co/ulMdFQtcDu
#
# GIVEAWAY iPhone!!!
#
# Gua mau bagi-bagi 3 iPhone 12 Mini sama OVO Cash total 5JUTA!
#
# RT dulu twit ini dan RT twit set… https://t.co/J1m7Ax6A2V
#
# RT @amyourss_: Gamau ah, mau ngamuk aja
#
# Tetap jadi baik ya.
#
# Yang terlihat kuat, bisa jadi sedang menyembunyikan masalah yang berat.
# Sekuat apapun seseorang, kadang juga butuh… https://t.co/n4tOpIhtTz
#
# Tidak semua hal harus selalu sesuai kemauan kamu, inget ada orang lain juga, jangan egois.
#
# Kadang kita perlu diam meskipun sudah tau apa yang sebenarnya terjadi, pengen liat aja dia jujur apa kaga.
#
# Pesan malam ini:
# Jangan ngandelin orang lain, yang bisa kamu andalkan cuma diri kamu sendiri.
#
# Jangan berharap banyak sama manusia, lebih banyak kecewanya.
#
# Jika memang untukmu, Allah akan permudah jalannya.
#
# Orang sabar kalau sampe marah biasanya serem.
#
# Oktober belum ada seminggu udah puyeng aja.
#
# RT @zaaaaarrrrrrrr: hooh tenan
#
# RT @marrieloey: affh iyh?
#
# RT @07arturrr: Urusan nya sama gua apaa anjjg wkwkwk
#
# Kalau mantan kamu bilang:
#
# "Aku sudah menemukan yang lebih baik dari kamu, aku lebih bahagia sekarang"
#
# Kamu bakal jawab apa?
#
# Ko belum tidur, ngapain?
#
# Jangan cuma mau dimengerti, cobalah untuk mengerti orang lain juga.
#
# Kalau emang dia sayang ya dia paham cara mengerti dan menghargai kamu.
#
# Setiap orang punya caranya masing-masing untuk mencintai.
#
# RT @ignatiuswisnu01: it goes📈📈📉📉📉📉📈📈📉📉📈📉📉📈📈📈📈📉📉📉📉📈📉📈📈📈
#
# RT @galihwicaksana_: pengen teriak jancokkk
#
# @widiasitaurus1 Ya Allah :(
# Turut berduka yang terdalam :(
#
# RT @widiasitaurus1: Full berduka kehilangan sepupu terbaik akibat tragedi bola kemarin:(
#
# Gimana kabarnya Senin pertama di Bulan Oktober?
# Full senyum kan? Ya kan ya dong
#
# Senin pertama di Bulan Oktober, semoga semua baik baik saja.
#
# BESOK SENIN
#
# Turut berduka yang sedalam-dalamnya, atas jatuhnya korban jiwa dalam pertandingan Arema VS Persebaya di stadion Kan… https://t.co/CUoDxM0Kfn
#
# Gimana semalem Malam Minggu pertama di Bulan Oktober?
#
# Dapet?
#
# Gimana kabarnya Oktober hari pertama?
#
# Malam ini Malam Minggu, apa rencana menarik kamu?
#
# Ya Allah semoga Oktober penuh berkah, aamiin.
#
# Baik baik ya Oktober, please banget ini.
#
# Selamat datang Oktober, semoga penuh dengan kabar baik.
#
# Bisa tidur cepet tanpa overthinking dulu adalah sebuah kebahagiaan tersendiri.
#
# September kali ini emang agak agak sadtember ya, hhu
#
# RT @amyourss_: Tired af, pengen dipeluk kekayaan
#
# RT @RIZKIDEDIUTOMO1: September full senyum pokok e✨
#
# RT @nadiadhanin: complicated, butuh uang BANGETT
#
# Jadi apa kabar September kamu?
# Happy
# Sad
# Complicated
# Tired af
# Butuh uang
#
# Terima kasih September, kali ini berasa banget :)
#
# September bener bener ngerasain naik turun naik turun naik hhu
# Semoga nanti Oktober naik naik terus ya kita semua, aamiin
#
# Ya Allah, lindungilah inisial R yang baik baik.
#
# Ya namanya juga hidup, ada aja bgstnya.
#
# RT @schnooglealy: @radenrauf cuma reyhan doang yg baiqq
#
# Tidak semua inisial R brengsek, banyak juga yang baik, asli dah.
#
# Ga ada
#
# Dari inisial R kita belajar bahwa.....
#
# Inisial R biasanya baik baik, yang brengsek itu oknum 😌
#
# Sudah bangun?
# Atau malah belum tidur?
#
# Inisial R kenape lagi?
#
# Orang kalau udah terlanjur sayang, ngeliat banyak red flag bisa diabaikan dan ditolerir dengan berbagai pembenaran,… https://t.co/6pYuO5pkMF
#
# RT @HeartWhisper16: @radenrauf Tergantung kondisi, kadang bisa jadi 4 orang

# %% [markdown]
# Masukan Ke dalam DataFrames Pandas

# %%
# Membuat kerangka data menggunakan sintaks berikut
dataset = pd.DataFrame(data = [tweet.text for tweet in tweets], columns = ['Tweets'])

# Tampilan kerangka data
display(dataset.head(100))
# Out:
#                                                Tweets
# 0                 Gimana Malam Minggunya?\nDah dapet?
# 1   RT @Anaknyagakbaik: @radenrauf Kasih tau cara ...
# 2   RT @cuma_narasi: @radenrauf #LoveStory  Apa ak...
# 3   RT @aahnitta: @radenrauf Dasar otak,bukan nya ...
# 4   RT @merrynblla: @radenrauf Malming ujan udh pa...
# ..                                                ...
# 95  Inisial R biasanya baik baik, yang brengsek it...
# 96             Sudah bangun?\nAtau malah belum tidur?
# 97                             Inisial R kenape lagi?
# 98  Orang kalau udah terlanjur sayang, ngeliat ban...
# 99  RT @HeartWhisper16: @radenrauf Tergantung kond...
#
# [100 rows x 1 columns]

# %%
dataset.to_csv('dataset_radenrauf.csv')

# %% [raw]
# Cleaning Word

# %% [markdown]
# Import Library Untuk Cleaning Word

# %%
import pandas as pd
import re
import string
import time
from copy import deepcopy

# %% [markdown]
# Loard Dataset

# %%
df = pd.read_csv('dataset_matanajwa.csv')

df.head()
# Out:
#    Unnamed: 0                                             Tweets
# 0           0                Gimana Malam Minggunya?\nDah dapet?
# 1           1  RT @Anaknyagakbaik: @radenrauf Kasih tau cara ...
# 2           2  RT @cuma_narasi: @radenrauf #LoveStory  Apa ak...
# 3           3  RT @aahnitta: @radenrauf Dasar otak,bukan nya ...
# 4           4  RT @merrynblla: @radenrauf Malming ujan udh pa...

# %%
df
# Out:
#      Unnamed: 0                                             Tweets
# 0             0                Gimana Malam Minggunya?\nDah dapet?
# 1             1  RT @Anaknyagakbaik: @radenrauf Kasih tau cara ...
# 2             2  RT @cuma_narasi: @radenrauf #LoveStory  Apa ak...
# 3             3  RT @aahnitta: @radenrauf Dasar otak,bukan nya ...
# 4             4  RT @merrynblla: @radenrauf Malming ujan udh pa...
# ..          ...                                                ...
# 193         193  Masih banyak orang baik di dunia ini, semoga k...
# 194         194  Jangankan ikut campur urusan orang, perkara ur...
# 195         195           RT @kapekalem: Hamdallah aman ga aman si
# 196         196  RT @ItsmeEpin: Masih sama mencoba kuat untuk m...
# 197         197                              RT @dnvtyd: Semoga :)
#
# [198 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  198 non-null    int64
#  1   Tweets      198 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 3.2+ KB

# %% [markdown]
# Preprocessing Dataset

# %% [markdown]
# Pertama lakukan instalasi modul ekphrasis

# %%
# !pip install ekphrasis
# Out:
# Collecting ekphrasis
#   Downloading ekphrasis-0.5.4-py3-none-any.whl (83 kB)
# Requirement already satisfied: tqdm in c:\users\acer\anaconda3\lib\site-packages (from ekphrasis) (4.64.0)
# Requirement already satisfied: nltk in c:\users\acer\anaconda3\lib\site-packages (from ekphrasis) (3.7)
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
# Requirement already satisfied: numpy in c:\users\acer\anaconda3\lib\site-packages (from ekphrasis) (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\acer\anaconda3\lib\site-packages (from ekphrasis) (3.5.1)
# Requirement already satisfied: colorama in c:\users\acer\anaconda3\lib\site-packages (from ekphrasis) (0.4.4)
# Collecting termcolor
#   Downloading termcolor-2.0.1-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: ujson in c:\users\acer\anaconda3\lib\site-packages (from ekphrasis) (5.1.0)
# Requirement already satisfied: wcwidth>=0.2.5 in c:\users\acer\anaconda3\lib\site-packages (from ftfy->ekphrasis) (0.2.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (3.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\acer\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->ekphrasis) (1.16.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\acer\anaconda3\lib\site-packages (from nltk->ekphrasis) (2022.3.15)
# Requirement already satisfied: joblib in c:\users\acer\anaconda3\lib\site-packages (from nltk->ekphrasis) (1.1.0)
# Requirement already satisfied: click in c:\users\acer\anaconda3\lib\site-packages (from nltk->ekphrasis) (8.0.4)
# Installing collected packages: termcolor, ftfy, ekphrasis
# Successfully installed ekphrasis-0.5.4 ftfy-6.1.1 termcolor-2.0.1

# %%
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons

text_processor = TextPreProcessor(
    # terms that will be normalized
    normalize=['email', 'percent', 'money', 'phone', 'user',
        'time', 'date', 'number'],
    # terms that will be annotated
    #annotate={"hashtag", "allcaps", "elongated", "repeated",'emphasis', 'censored'},
    annotate={"hashtag"},
    fix_html=True,  # fix HTML tokens
    
    # corpus from which the word statistics are going to be used 
    # for word segmentation 
    segmenter="twitter", 
    
    # corpus from which the word statistics are going to be used 
    # for spell correction
    corrector="twitter", 
    
    unpack_hashtags=True,  # perform word segmentation on hashtags
    unpack_contractions=True,  # Unpack contractions (can't -> can not)
    spell_correct_elong=False,  # spell correction for elongated words
    
    # select a tokenizer. You can use SocialTokenizer, or pass your own
    # the tokenizer, should take as input a string and return a list of tokens
    tokenizer=SocialTokenizer(lowercase=True).tokenize,
    
    # list of dictionaries, for replacing tokens extracted from the text,
    # with other expressions. You can pass more than one dictionaries.
    dicts=[emoticons]
)
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\ekphrasis\classes\tokenizer.py:225: FutureWarning: Possible nested set at position 2190
#   self.tok = re.compile(r"({})".format("|".join(pipeline)))
# Word statistics files not found!
# Downloading... done!
# Unpacking... done!
# Reading twitter - 1grams ...
# generating cache file for faster loading...
# reading ngrams C:\Users\acer\.ekphrasis\stats\twitter\counts_1grams.txt
# Reading twitter - 2grams ...
# generating cache file for faster loading...
# reading ngrams C:\Users\acer\.ekphrasis\stats\twitter\counts_2grams.txt
# C:\Users\acer\anaconda3\lib\site-packages\ekphrasis\classes\exmanager.py:14: FutureWarning: Possible nested set at position 42
#   regexes = {k.lower(): re.compile(self.expressions[k]) for k, v in
# Reading twitter - 1grams ...

# %%
# panggil ekphrasis

def bersih_data(text):
    return " ".join(text_processor.pre_process_doc(text))

# %%
# fungsi dari AMS 01-03. silakan cek bagaimana saya merubah menjadi fungsi

def non_ascii(text):
    return text.encode('ascii', 'replace').decode('ascii')

def remove_space(text):
    return " ".join(text.split())

def remove_emoji(text):
    return ' '.join(re.sub("([x#][A-Za-z0-9]+)"," ", text).split())

def remove_tab(text):
    return text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")

def remove_tab2(text):
    return re.sub('\s+',' ',text)

def remove_rt(text):
    return text.replace('RT'," ")

def remove_mention(text):
    return ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())

def remove_incomplete_url(text):
    return text.replace("http://", " ").replace("https://", " ")

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def change_stripe(text):
    return text.replace('-'," ")

def lower(text):
    return text.lower()

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def lower(text):
    return text.lower()

def remove_whitespace_LT(text):
    return text.strip()

def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

def remove_punctuation(text):
    remove = string.punctuation
    remove = remove.replace("_", "") # don't remove hyphens
    pattern = r"[{}]".format(remove) # create the pattern
    return re.sub(pattern, "", text)

# %%
# hapus untuk <>
def remove_number_eks(text):
    return text.replace('<number>'," ")

def remove_angka(text):
    return re.sub(r"\d+", "", text) 

def remove_URL_eks(text):
    return text.replace('URL'," ").replace('url'," ")

def space_punctuation(text):
    return re.sub('(?<! )(?=[.,!?()])|(?<=[.,!?()])(?! )', r' ', text)

# %% [markdown]
# Mulai Proses pembersih

# %%
i = 0
final_string = []
s = ""
for text in df['Tweets'].values:
    filteredSentence = []
    EachReviewText = ""
    proc = remove_rt(text)
    proc = lower(proc)
    proc = change_stripe(proc)
    proc = remove_emoji(proc)
    proc = remove_tab(proc)
    proc = remove_tab2(proc)
    proc = non_ascii(proc)
    proc = remove_incomplete_url(proc)
    proc = remove_excessive_dot(proc)
    proc = remove_whitespace_LT(proc)
    proc = remove_whitespace_multiple(proc)
    proc = remove_single_char(proc)
    proc = space_punctuation(proc)
    proc = remove_punctuation(proc)
    proc = remove_space(proc)
    proc = bersih_data(proc)
    proc = remove_number_eks(proc)
    proc = remove_angka(proc) 
    proc = remove_URL_eks(proc)
    EachReviewText = proc
    final_string.append(EachReviewText)

# %%
df["step01"] = final_string

# %%
df.head(10)
# Out:
#    Unnamed: 0                                             Tweets  \
# 0           0                Gimana Malam Minggunya?\nDah dapet?
# 1           1  RT @Anaknyagakbaik: @radenrauf Kasih tau cara ...
# 2           2  RT @cuma_narasi: @radenrauf #LoveStory  Apa ak...
# 3           3  RT @aahnitta: @radenrauf Dasar otak,bukan nya ...
# 4           4  RT @merrynblla: @radenrauf Malming ujan udh pa...
# 5           5  DEAR TWITTER, PLEASEE DO YOUR MAGIC!\n\nBiro J...
# 6           6       RT @stfusaff: @radenrauf bisa gtu sambelnya😭
# 7           7    RT @osealov: @radenrauf https://t.co/YcH5sigCJ1
# 8           8  RT @nadhifanfs_: @radenrauf Cuangki bang https...
# 9           9  Sore sore ujan ujan emang paling bener makan B...
#
#                                               step01
# 0                   gimana malam minggunya dah dapet
# 1  anaknyagakbaik radenrauf kasih tau cara dapeti...
# 2  cuma_narasi radenrauf apa aku harus pakai asur...
# 3  aahnitta radenrauf dasar otak bukan nya di isi...
# 4  merrynblla radenrauf malming ujan udh pasti do...
# 5  dear twitter pleasee do your magic biro jodoh ...
# 6              stfusaff radenrauf bisa gtu sambelnya
# 7                       osealov radenrauf coychsigcj
# 8      nadhifanfs_ radenrauf cuangki bang coufinftha
# 9  sore sore ujan ujan emang paling bener makan b...

# %%
Hapus Data Kosong
# Out:
#   Input In [21]
#     Hapus Data Kosong
#           ^
# SyntaxError: invalid syntax

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  198 non-null    int64
#  1   Tweets      198 non-null    object
#  2   step01      198 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 4.8+ KB

# %%
df_hapus = df[~df['step01'].str.contains(" ")]

# %%
df_hapus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      int64
#  1   Tweets      0 non-null      object
#  2   step01      0 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 0.0+ bytes

# %%
df_hapus.head(10)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Tweets, step01]
# Index: []

# %%
df_new = df[~df.isin(df_hapus)].dropna()

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  198 non-null    int64
#  1   Tweets      198 non-null    object
#  2   step01      198 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 4.8+ KB

# %%
df_new
# Out:
#      Unnamed: 0                                             Tweets  \
# 0             0                Gimana Malam Minggunya?\nDah dapet?
# 1             1  RT @Anaknyagakbaik: @radenrauf Kasih tau cara ...
# 2             2  RT @cuma_narasi: @radenrauf #LoveStory  Apa ak...
# 3             3  RT @aahnitta: @radenrauf Dasar otak,bukan nya ...
# 4             4  RT @merrynblla: @radenrauf Malming ujan udh pa...
# ..          ...                                                ...
# 193         193  Masih banyak orang baik di dunia ini, semoga k...
# 194         194  Jangankan ikut campur urusan orang, perkara ur...
# 195         195           RT @kapekalem: Hamdallah aman ga aman si
# 196         196  RT @ItsmeEpin: Masih sama mencoba kuat untuk m...
# 197         197                              RT @dnvtyd: Semoga :)
#
#                                                 step01
# 0                     gimana malam minggunya dah dapet
# 1    anaknyagakbaik radenrauf kasih tau cara dapeti...
# 2    cuma_narasi radenrauf apa aku harus pakai asur...
# 3    aahnitta radenrauf dasar otak bukan nya di isi...
# 4    merrynblla radenrauf malming ujan udh pasti do...
# ..                                                 ...
# 193  masih banyak orang baik di dunia ini semoga ka...
# 194  jangankan ikut campur urusan orang perkara uru...
# 195                kapekalem hamdallah aman ga aman si
# 196  itsmeepin masih sama mencoba kuat untuk melewa...
# 197                                      dnvtyd semoga
#
# [198 rows x 3 columns]

# %% [markdown]
# Normalisasi kata slang menjadi baku

# %%
# token
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\acer\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
def word_tokenize_wrapper(text):
  return word_tokenize(text)

# %%
df_new['tokens'] = df["step01"].apply(word_tokenize_wrapper)

# %%
df_new.head(10)
# Out:
#    Unnamed: 0                                             Tweets  \
# 0           0                Gimana Malam Minggunya?\nDah dapet?
# 1           1  RT @Anaknyagakbaik: @radenrauf Kasih tau cara ...
# 2           2  RT @cuma_narasi: @radenrauf #LoveStory  Apa ak...
# 3           3  RT @aahnitta: @radenrauf Dasar otak,bukan nya ...
# 4           4  RT @merrynblla: @radenrauf Malming ujan udh pa...
# 5           5  DEAR TWITTER, PLEASEE DO YOUR MAGIC!\n\nBiro J...
# 6           6       RT @stfusaff: @radenrauf bisa gtu sambelnya😭
# 7           7    RT @osealov: @radenrauf https://t.co/YcH5sigCJ1
# 8           8  RT @nadhifanfs_: @radenrauf Cuangki bang https...
# 9           9  Sore sore ujan ujan emang paling bener makan B...
#
#                                               step01  \
# 0                   gimana malam minggunya dah dapet
# 1  anaknyagakbaik radenrauf kasih tau cara dapeti...
# 2  cuma_narasi radenrauf apa aku harus pakai asur...
# 3  aahnitta radenrauf dasar otak bukan nya di isi...
# 4  merrynblla radenrauf malming ujan udh pasti do...
# 5  dear twitter pleasee do your magic biro jodoh ...
# 6              stfusaff radenrauf bisa gtu sambelnya
# 7                       osealov radenrauf coychsigcj
# 8      nadhifanfs_ radenrauf cuangki bang coufinftha
# 9  sore sore ujan ujan emang paling bener makan b...
#
#                                               tokens
# 0             [gimana, malam, minggunya, dah, dapet]
# 1  [anaknyagakbaik, radenrauf, kasih, tau, cara, ...
# 2  [cuma_narasi, radenrauf, apa, aku, harus, paka...
# 3  [aahnitta, radenrauf, dasar, otak, bukan, nya,...
# 4  [merrynblla, radenrauf, malming, ujan, udh, pa...
# 5  [dear, twitter, pleasee, do, your, magic, biro...
# 6        [stfusaff, radenrauf, bisa, gtu, sambelnya]
# 7                   [osealov, radenrauf, coychsigcj]
# 8  [nadhifanfs_, radenrauf, cuangki, bang, coufin...
# 9  [sore, sore, ujan, ujan, emang, paling, bener,...

# %%
normalized_word = pd.read_csv('kamus_clean.csv')

# %%
normalized_word_dict = {}

for index, row in normalized_word.iterrows():
    if row[0] not in normalized_word_dict:
        normalized_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalized_word_dict[term] if term in normalized_word_dict else term for term in document]

# %%
df_new['final_tokens'] = df_new['tokens'].apply(normalized_term)

# %%
i=0
final_string_tokens = []
for text in df_new['final_tokens'].values:
    EachReviewText = ""
    EachReviewText = ' '.join(text)
    final_string_tokens.append(EachReviewText)

# %%
df_new["step02"] = final_string_tokens

# %%
df_new.head(10)
# Out:
#    Unnamed: 0                                             Tweets  \
# 0           0                Gimana Malam Minggunya?\nDah dapet?
# 1           1  RT @Anaknyagakbaik: @radenrauf Kasih tau cara ...
# 2           2  RT @cuma_narasi: @radenrauf #LoveStory  Apa ak...
# 3           3  RT @aahnitta: @radenrauf Dasar otak,bukan nya ...
# 4           4  RT @merrynblla: @radenrauf Malming ujan udh pa...
# 5           5  DEAR TWITTER, PLEASEE DO YOUR MAGIC!\n\nBiro J...
# 6           6       RT @stfusaff: @radenrauf bisa gtu sambelnya😭
# 7           7    RT @osealov: @radenrauf https://t.co/YcH5sigCJ1
# 8           8  RT @nadhifanfs_: @radenrauf Cuangki bang https...
# 9           9  Sore sore ujan ujan emang paling bener makan B...
#
#                                               step01  \
# 0                   gimana malam minggunya dah dapet
# 1  anaknyagakbaik radenrauf kasih tau cara dapeti...
# 2  cuma_narasi radenrauf apa aku harus pakai asur...
# 3  aahnitta radenrauf dasar otak bukan nya di isi...
# 4  merrynblla radenrauf malming ujan udh pasti do...
# 5  dear twitter pleasee do your magic biro jodoh ...
# 6              stfusaff radenrauf bisa gtu sambelnya
# 7                       osealov radenrauf coychsigcj
# 8      nadhifanfs_ radenrauf cuangki bang coufinftha
# 9  sore sore ujan ujan emang paling bener makan b...
#
#                                               tokens  \
# 0             [gimana, malam, minggunya, dah, dapet]
# 1  [anaknyagakbaik, radenrauf, kasih, tau, cara, ...
# 2  [cuma_narasi, radenrauf, apa, aku, harus, paka...
# 3  [aahnitta, radenrauf, dasar, otak, bukan, nya,...
# 4  [merrynblla, radenrauf, malming, ujan, udh, pa...
# 5  [dear, twitter, pleasee, do, your, magic, biro...
# 6        [stfusaff, radenrauf, bisa, gtu, sambelnya]
# 7                   [osealov, radenrauf, coychsigcj]
# 8  [nadhifanfs_, radenrauf, cuangki, bang, coufin...
# 9  [sore, sore, ujan, ujan, emang, paling, bener,...
#
#                                         final_tokens  \
# 0             [gimana, malam, minggunya, dah, dapet]
# 1  [anaknyagakbaik, radenrauf, kasih, tau, cara, ...
# 2  [cuma_narasi, radenrauf, apa, aku, harus, paka...
# 3  [aahnitta, radenrauf, dasar, otak, bukan, nya,...
# 4  [merrynblla, radenrauf, malming, ujan, udh, pa...
# 5  [dear, twitter, pleasee, do, your, magic, biro...
# 6        [stfusaff, radenrauf, bisa, gtu, sambelnya]
# 7                   [osealov, radenrauf, coychsigcj]
# 8  [nadhifanfs_, radenrauf, cuangki, bang, coufin...
# 9  [sore, sore, ujan, ujan, emang, paling, bener,...
#
#                                               step02
# 0                   gimana malam minggunya dah dapet
# 1  anaknyagakbaik radenrauf kasih tau cara dapeti...
# 2  cuma_narasi radenrauf apa aku harus pakai asur...
# 3  aahnitta radenrauf dasar otak bukan nya di isi...
# 4  merrynblla radenrauf malming ujan udh pasti do...
# 5  dear twitter pleasee do your magic biro jodoh ...
# 6              stfusaff radenrauf bisa gtu sambelnya
# 7                       osealov radenrauf coychsigcj
# 8      nadhifanfs_ radenrauf cuangki bang coufinftha
# 9  sore sore ujan ujan emang paling bener makan b...

# %% [markdown]
# Simpan Clean Dataset

# %%
df_new.to_csv('clean_dataset_')
